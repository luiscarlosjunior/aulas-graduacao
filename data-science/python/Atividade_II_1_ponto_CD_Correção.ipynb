# %% [markdown]
# # Introdução
# Esse exercício referece ao que foi visto nas aulas de coleções. A ideia aqui é permitir que os alunos possam apresentar conclusões sobre o resultado obtido. Os dados aqui utilizados serão gerados de maneira pseudoaleatórios, portanto cada execução terá um resultado único
# > obs: Execute em ordem para não haver problemas
# > links de referências:
# > [Coleções em python](https://phylos.net/2021-03-08/python-sequencias-e-colecoes#:~:text=Cole%C3%A7%C3%B5es%20s%C3%A3o%20conteineres%20de%20dados.%20No%20m%C3%B3dulo%20b%C3%A1sico,n%C3%A3o%20ordenada%20e%20n%C3%A3o%20indexada%2C%20sem%20membros%20duplicados.)

# %% [markdown]
# ## Perguntas de pesquisa e implementação
#
# > (Crie uma nova célula de texto ou escreva na célula de código abaixo)

# %% [markdown]
# ### Quais são as diferenças entre tupla e lista? Implemente um exemplo de cada um e apresente seus itens

# %%
"""
Resumidamente as diferenças entre lista e tupla são:
Mutabilidade
Sintaxe
Desempenho
uso 
"""

lista_compras = ['Arroz', 'Feijão', ['Bolacha', 'Chocolate em barras'], 'Suco de uva']
print(lista_compras)


tuplas_nome_e_cpf = (('João', 123456), ('Maria', 123456), ('Pamela', 963258))
print(tuplas_nome_e_cpf)
# Out:
# ['Arroz', 'Feijão', ['Bolacha', 'Chocolate em barras'], 'Suco de uva']
# (('João', 123456), ('Maria', 123456), ('Pamela', 963258))

# %% [markdown]
# ### Quais sãos as diferenças entre lista e dicionários em python? Implemente um exemplo simples de cada e apresente seus itens

# %%
"""
Lista é uma estrutura de dados mutável e flexivel. O uso é aconselhado quando
temos dados que não sabemos se sofrerão modificação em seus tipos, valores
e tamanho. Porém, sofre com a perfomance em grande quantidade de dados.
Dicionários ou mapa é uma estrutura de dados que utiliza o conceito de
chave e valor, no qual é feito, ao contrário de lista e tuplas, associações
Dicionários possuem as duas características, mutável e imutável. Mutável
aplica em suas chaves, enquanto os valores são imutáveis, ou podem sofrer
modificação 
Resumidamente as diferenças são: 
Acesso
Mutabilidade
Sintaxe
Uso
"""

lista_idade = [25,26,35,12,65,32,22]
print(lista_idade)

dicionario_pessoas = {
  "Nomes": ["João da Silva Santos", "Maria Mariana"],
  "Cpf": ["123456", "123456"],
  "Idade": [25, 25],
  "Hobby": ["Gosta de ler", "Gosta de estudar"]
}
lista_nome = dicionario_pessoas.get("Nomes")
print(lista_nome[0])
# Out:
# [25, 26, 35, 12, 65, 32, 22]
# João da Silva Santos

# %% [markdown]
# ### Em python o que significa quando um objeto é mutavel e imutavel? Quais são suas diferenças? Implemente ao menos um de cada na célula abaixo

# %%
"""
Em python, objetos imutáveis são objetos que não podem ser alterados após
definidos e objetos mutáveis podem ser alterados após a sua definição.
As diferenças estão no uso e performance. Objetos imutáveis possuem uma
melhor otimização e rápida procura de itens
"""

exemplo_mutavel = [1,2,3,4,5]
print(type(exemplo_mutavel))
exemplo_imutavel = (1,2,3,4,5)
print(type(exemplo_imutavel))
# Out:
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# ## Exercício prático
# Uma empresa conhecida no ramo de aplicativos de inteligência artificial (IA) conhecida como **ConfIA+** gostaria de conhcer o perfil do novo público de um aplicativo lançado recentemente. O cliente acredita que através da idade e salários fornecidos (sem nomes por questões de LGPD) poderá ser feito o mapeamento do perfil e tomar decisões estratégicas. Para isso, chegou até a sua equipe uma série de operações a serem realizadas e por fim entregarmos uma conclusão para apresentar para o cliente.

# %% [markdown]
# ## Criando os dados que serão utilizados para a atividade (Mock)

# %% [markdown]
# ### Dados obtidos do cliente. A lista abaixo possui uma tupla com a idade e a somatória dos gastos em um determinado serviço

# %%
# SÓ EXECUTAR A CÉLULA, NÃO PRECISA ALTERAR
# Importa biblioteca para usar números aleatórios
import random as numero_aleatorio # a palavra 'as' indica que queremos dar um apelido a essa biblioteca
# Defini o tamanho da população
quantidade_pessoas = numero_aleatorio.randint(1000, 5000)

# %% [markdown]
# Aqui será feito o preenchimento da lista com idade e gasto por idade (SÓ EXECUTAR)

# %%
# SÓ EXECUTAR A CELULA, NÃO PRECISA ALTERAR
# Preenchimento da lista dos dados com números aleatórios. 
lista = []
for indice in range(quantidade_pessoas):
  idade = numero_aleatorio.randint(18, 40) # Gera valores entre 18 e 40
  salario = numero_aleatorio.randint(2800, 10000) # Gera valores entre 2800 até 10000
  lista.append((idade, salario))
print(lista)
# Out:
# [(28, 9601), (25, 9472), (23, 7471), (18, 7943), (18, 7834), (35, 7512), (29, 9780), (34, 2952), (36, 9541), (34, 3269), (29, 5055), (34, 8309), (31, 2821), (33, 6909), (34, 8508), (25, 4801), (39, 8141), (19, 3119), (19, 2891), (35, 3010), (18, 8265), (30, 9704), (38, 5739), (36, 5853), (39, 9331), (20, 6772), (35, 5748), (21, 6813), (29, 4025), (35, 3164), (20, 5356), (20, 3803), (29, 6732), (26, 6486), (20, 9545), (33, 9236), (36, 9897), (18, 7132), (28, 8791), (32, 7895), (40, 5279), (35, 8886), (19, 7009), (28, 3759), (27, 6911), (29, 5406), (25, 9817), (23, 7851), (34, 9346), (35, 3487), (31, 7634), (34, 9843), (21, 8258), (32, 7176), (35, 9269), (24, 3715), (33, 6846), (30, 6726), (28, 3964), (29, 5782), (34, 4455), (28, 3524), (35, 4205), (21, 6468), (22, 5981), (36, 7805), (27, 4658), (29, 9537), (31, 5712), (40, 9969), (30, 3395), (33, 6777), (38, 3394), (39, 6410), (24, 8235), (32, 7474), (31, 7638), (27, 7111), (27, 5068), (30, 3946), (19, 5397), (25, 5854), (40, 7470), (39, 9322), (39, 5793), (34, 8810), (36, 2945), (31, 3725), (29, 3988), (29, 3797), (33, 6489), (33, 4733), (26, 4625), (30, 4927), (21, 5091), (32, 8286), (34, 7108), (28, 5980), (35, 2800), (29, 3284), (24, 8765), (
# %% [markdown]
# ## Atividade prática

# %% [markdown]
# ### 1) Apresente o tipo e a quantidade de itens da variavel lista declarada e atribuida acima
#
# O cliente quer saber quantas pessoas estão usando o seu produto, para isso, apresente a quantidade de itens presente na lista e também o tipo da lista como um incremento

# %%
# Preencha com sua resposta
print(f'O quantidade total de pessoas é de {len(lista)}')
print(f'O tipo do objeto é {type(lista)}')
# Out:
# O tamanho total de pessoas é de 3822
# O tipo do objeto é <class 'list'>

# %% [markdown]
# ### 2) Apresente a primeiro item e o último item da lista criada acima. Cada item dessa lista é uma tupla
#
# O cliente é uma pessoa desconfiada e preocupado com o seu negócio. Para tentar diminuir a confiança dele ele teve acesso ao primero e último item da lista para confirmar com a lista que temos basta apresentar o primeiro e o último item dessa lista.

# %%
# Preencha com sua resposta
print(lista[0])
print(lista[-1]) # lista[len(lista)-1]
# Out:
# (33, 4605)
# (18, 6361)

# %% [markdown]
# ### 3) Apresente a soma dos cinco primeiros salários da lista criada acima
#
# O cliente ainda está desconfiado, então ele sugeriu que você e sua equipe apresentasse a soma dos **cinco primeiros salários** da lista obtida por ele, assim ele poderá confirmar os dados que você possui e o que ele possui

# %%
# Preencha com sua resposta
soma = 0
for indice in range(5):
  soma += lista[indice][1]
print(f'A soma dos cinco primeiros salários é de: R$ {soma}')

print(f'\n\n')
soma = 0
for item in lista[:5]:
  soma = soma + item[1]
print(f'A soma dos cinco primeiros salários é de: R$ {soma}')
# Out:
# A soma dos cinco primeiros salários é de: R$ 42321
#
#
#
# A soma dos cinco primeiros salários é de: R$ 42321

# %% [markdown]
# ### 4) Apresente a soma dos cinco últimos salários da lista acima
# Mais uma prova de conceito que o cliente quer fazer. Ele solicitou agora a soma dos últimos cinco salarios da lista criada acima

# %%
soma = 0
for indice in range(-5, 0, 1):
  soma += lista[indice][1]
print(f'A soma dos cinco primeiros salários é de: R$ {soma}')

print(f'\n\n')

soma = 0
for item in lista[-5:]:
  salario = item[1]
  soma = soma + salario
print(f'A soma dos cinco primeiros salários é de: R$ {soma}')
# Out:
# A soma dos cinco primeiros salários é de: R$ 30799
#
#
#
# A soma dos cinco primeiros salários é de: R$ 30799

# %% [markdown]
# ### 5) Faça a média das idades entre a posição 25 até 155 e apresente a média de seus salários em uma linha
#
# Agora o grupo de executivos do cliente solicitou uma tarefa um pouco estranha, porém faz sentido em estatística. Ele quer pegar uma amostra dessa população (lista) criada verificar se ela está bem distribuida. Para isso ele pediram para realizar a média das idades e salário das posições 25 até 155.

# %%
# Preecha com sua resposta
soma = 0
for indice in range(25,156):
  salario = lista[indice][1]
  soma += salario


quantidade = 155 - 25
print(f'A média de salário entre 25 e 155 é de R$ {round(soma/quantidade, 2)}')

print(f'\n\n')


soma = 0
for item in lista[25:156]:
  salario = item[1]
  soma += salario

quantidade = 155 - 25
print(f'A média de salário entre 25 e 155 é de R$ {round(soma/quantidade, 2)}')
# Out:
# A média de salário entre 25 e 155 é de R$ 6305.41
#
#
#
# A média de salário entre 25 e 155 é de R$ 6305.41

# %% [markdown]
# ### 6) Dado a lista acima, faça os seguintes cálculos: (Obrigatório realizar com laço de repetição, sem usar funções de soma ou ajuda de bibliotecas externas)
#
# Faça a somatória das idades e realize a média com duas casas decimais arredondadas
# Faça a somatória dos gastos e realize a média com duas casas decimais truncadas

# %%
soma = 0
for indice in range(len(lista)):
  idade = lista[indice][0]
  soma += idade

print(f'A média de idades das pessoas que usam o app é de {int(soma/len(lista))} anos')

print('\n\n')

# Média de idades
soma = 0
for item in lista:
  idade = item[0]
  soma += idade
print(f'A média de idades das pessoas que usam o app é de {int(soma/len(lista))} anos')
# Out:
# A média de idades das pessoas que usam o app é de 29 anos
#
#
#
# A média de idades das pessoas que usam o app é de 29 anos

# %%
soma = 0
for indice in range(len(lista)):
  salario = lista[indice][1]
  soma += salario
print(f'A média salarial dos clientes do app é de R$ {round(soma/len(lista), 2)}')

print('\n\n')

# Média dos salários
soma = 0
for item in lista:
  salario = item[1]
  soma += salario
print(f'A média salarial dos clientes do app é de R$ {round(soma/len(lista), 2)}')
# Out:
# A média salarial dos clientes do app é de R$ 6439.7
#
#
#
# A média salarial dos clientes do app é de R$ 6439.7

# %% [markdown]
# ### **ESCREVA AQUI A CONCLUSÃO**
#
# > obs: Escreva a sua conclusão dos resultados obtidos a cima. Lembre-se, apresentação em Data Science é tão importante quanto o algoritmo em sí
#
# Com base na análise dos dados coletados, foi possível identificar que a idade média dos nossos clientes é de 29 anos e que o salário médio é de R$ 6000. Essas informações são essenciais para a tomada de decisões da empresa em diversas áreas, como marketing, vendas e recursos humanos.
#
# Por exemplo, o departamento de marketing pode usar essas informações para ajustar suas campanhas publicitárias e estratégias de marketing para atender melhor a esse público específico. Já a equipe de vendas pode ajustar suas abordagens de vendas para melhor atender às necessidades dos clientes com essa faixa etária e nível salarial.
#
# Além disso, a equipe de recursos humanos pode usar essas informações para avaliar e ajustar as políticas de remuneração e benefícios da empresa para garantir que estejam em linha com a média salarial do mercado para essa faixa etária. Também pode ajudar na identificação de áreas com alta demanda de contratação e garantir que a empresa possua a força de trabalho necessária para atender às necessidades dos clientes.
#
# Em resumo, a compreensão da faixa etária e do salário médio dos nossos clientes é crucial para o sucesso dos negócios e para a tomada de decisões estratégicas da empresa. As informações obtidas através da análise dos dados coletados permitem que a empresa adapte suas estratégias e políticas para atender melhor às necessidades desse público específico.
